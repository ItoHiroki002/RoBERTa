# %% [markdown]
# # Sentence-BERTの学習コード
#
# 卒論に記載の略称を用いています。
# valid_tsvの指定等はjsnliのdevを使う等が適切です。

# %%
# MNRLossSN
# !python ./sbert_train_mnr_sn.py --pretrained_model_path="alabnii/jmedroberta-base-sentencepiece"\
    --trained_result_path="./jmedroberta_mnr_sn_20" \
    --checkpoint_output_path="./jmedroberta_mnr_sn_20_c" \
    --train_tsv_path="../../resources/dataset/nli/tmjsnli_v4_d/tmjsnli_all_train.tsv" \
    --valid_tsv_path="../../resources/dataset/nli/tmjsnli_v4/tmjsnli_all_dev.tsv" \
    --test_tsv_path=".././/resources/dataset/nli/tmjsnli_v4/tmjsnli_dev.tsv" \
    --num_epochs=20 --learning_rate="2e-05" --seed=42 --batch_size=64

# MNRLossHN
# !python ./sbert_train_mnr_hn.py --pretrained_model_path="alabnii/jmedroberta-base-sentencepiece"\
    --trained_result_path="./jmedroberta_mnr_hn_20" \
    --checkpoint_output_path="./jmedroberta_mnr_hn_20_c" \
    --train_tsv_path="../../resources/dataset/nli/tmjsnli_v4_d/tmjsnli_all_train.tsv" \
    --valid_tsv_path="../../resources/dataset/nli/tmjsnli_v4/tmjsnli_all_dev.tsv" \
    --test_tsv_path="../../resources/dataset/nli/tmjsnli_v4/tmjsnli_dev.tsv" \
    --num_epochs=20 --learning_rate="2e-05" --seed=42 --batch_size=64
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at alabnii/jmedroberta-base-sentencepiece and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2026-01-09 08:43:35 - Use pytorch device_name: cuda:0
# 2026-01-09 08:43:39 - Warmup-steps: 9720
# {'loss': 3.3502, 'grad_norm': 11.04977035522461, 'learning_rate': 1.0267489711934157e-06, 'epoch': 0.102880658436214}
# {'loss': 2.0285, 'grad_norm': 10.114831924438477, 'learning_rate': 2.0555555555555555e-06, 'epoch': 0.205761316872428}
# {'loss': 1.6526, 'grad_norm': 10.048111915588379, 'learning_rate': 3.084362139917696e-06, 'epoch': 0.30864197530864196}
# {'loss': 1.4912, 'grad_norm': 8.449140548706055, 'learning_rate': 4.1131687242798354e-06, 'epoch': 0.411522633744856}
# ...

# %%
# 重みのあるMNRLossSNと言及していたやつ
# !python ./sbert_train_weighted_mnr.py --pretrained_model_path="alabnii/jmedroberta-base-sentencepiece" \
    --trained_result_path="./jmedroberta_weighted_mnr" \
    --checkpoint_output_path="./jmedroberta_weighted_mnr" \
    --train_tsv_path="../../resources/dataset/nli/tmjsnli_v4_d/tmjsnli_all_train.tsv" \
    --valid_tsv_path="../../resources/dataset/nli/tmjsnli_v4/tmjsnli_all_dev.tsv" \
    --test_tsv_path="../../resources/dataset/nli/tmjsnli_v4/tmjsnli_dev.tsv" \
    --num_epochs=10 --learning_rate="2e-05" --seed=42 --batch_size=64 --weight=0.3
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at alabnii/jmedroberta-base-sentencepiece and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2026-01-13 14:27:05 - Use pytorch device_name: cuda:0
# 2026-01-13 14:27:09 - Warmup-steps: 4860
# Traceback (most recent call last):
#   File "/home/itohiroki/kubert/BERT-TrainScripts/sbert_train/./sbert_train_weighted_mnr.py", line 90, in <module>
#     model.fit(train_objectives=[(train_dataloader, train_loss)],
#   File "/home/itohiroki/kubert/.venv/lib/python3.10/site-packages/sentence_transformers/fit_mixin.py", line 408, in fit
#     trainer.train(resume_from_checkpoint=resume_from_checkpoint)
#   File "/home/itohiroki/kubert/.venv/lib/python3.10/site-packages/transformers/trainer.py", line 2325, in train
#     return inner_training_loop(
# ...
