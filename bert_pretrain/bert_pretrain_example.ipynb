# %%
import os
print("Exists:", os.path.exists("../bert_preprocess/jmedroberta_bf_randinit"))


# !python bert_pretrain.py \
    --before_train_model="alabnii/jmedroberta-base-sentencepiece" \
    --trained_model="jmedroberta_noexpansion" --epochs=20 \
    --corpus="../../resources/corpus/chui_word_dic_corpus.txt"
# Out:
# Exists: True
# /home/itohiroki/kubert/.venv/lib/python3.10/site-packages/transformers/data/datasets/language_modeling.py:119: FutureWarning: This dataset will be removed from the library soon, preprocessing should be handled with the 🤗 Datasets library. You can have a look at this example script for pointers: https://github.com/huggingface/transformers/blob/main/examples/pytorch/language-modeling/run_mlm.py
#   warnings.warn(
# {'loss': 2.1131, 'grad_norm': 15.463299751281738, 'learning_rate': 4.750069910514542e-05, 'epoch': 1.0}
# {'loss': 1.6579, 'grad_norm': 17.138978958129883, 'learning_rate': 4.500069910514541e-05, 'epoch': 2.0}
# {'loss': 1.4763, 'grad_norm': 27.374858856201172, 'learning_rate': 4.2500699105145413e-05, 'epoch': 3.0}
# {'loss': 1.3515, 'grad_norm': 13.392046928405762, 'learning_rate': 4.000069910514542e-05, 'epoch': 4.0}
# {'loss': 1.2295, 'grad_norm': 17.5468807220459, 'learning_rate': 3.7500699105145414e-05, 'epoch': 5.0}
# ...

# %%
import matplotlib.pyplot as plt

losses = [
    2.1131, 1.6579, 1.4763, 1.3515, 1.2295,
    1.1484, 1.0774, 1.0322, 0.9833, 0.9322,
    0.8676, 0.8828, 1.3993, 1.3386, 1.3121,
    1.2993, 1.2332, 1.3202, 1.1664, 1.0679
]

epochs = list(range(1, len(losses) + 1))

plt.figure(figsize=(10, 5))
plt.plot(epochs, losses, marker='o')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss per Epoch")
plt.grid(True)
plt.tight_layout()
plt.show()
